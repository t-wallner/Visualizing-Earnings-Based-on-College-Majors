# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
print(recent_grads.iloc[0])
print(recent_grads.head(4))
print(recent_grads.tail(4))
recent_grads.describe()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
raw_data_count = recent_grads.shape[0]
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print("Raw row count: "+ str(raw_data_count))
print("Cleaned row count: "+str(cleaned_data_count))
# Out:
# Raw row count: 173
# Cleaned row count: 172

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title='Employed vs. Sample_size', figsize=(5,10))

# %%
recent_grads.plot(x="Sample_size",y="Median",kind="scatter",title="Sample_size vs Median")

# %%
recent_grads.plot(x="Sample_size",y="Unemployment_rate",kind="scatter",title="Sample_size vs Unemployment_rate")

# %%
recent_grads.plot(x="Full_time",y="Median",kind="scatter",title="Full_time vs Median")

# %%
recent_grads.plot(x="ShareWomen",y="Unemployment_rate",kind="scatter",title="ShareWomen vs Unemployment_rate")

# %%
recent_grads.plot(x="Men",y="Median",kind="scatter",title="Men vs Median")

# %%
recent_grads.plot(x="Women",y="Median",kind="scatter",title="Women vs Median")

# %%
# Do students that majored in subjects that were majority female make more money?
recent_grads.plot(x="ShareWomen", y="Median",kind="scatter", title="ShareWomen vs Median")
# Slight negative correlation: Students that majored in mjority female subjects are likely to make less money

# %%
recent_grads.plot(x="Full_time",y="Median",kind="scatter",title="Full time vs Median")
# no statistically significant link

# %%
recent_grads['Sample_size'].hist(bins=25)

# %%
recent_grads['Median'].hist(bins=25)

# %%
recent_grads['Employed'].hist(bins=25)

# %%
recent_grads["Full_time"].hist(bins=40)

# %%
recent_grads["ShareWomen"].hist(bins=20)

# %%
recent_grads["Unemployment_rate"].hist(bins=20)

# %%
recent_grads["Men"].hist(bins=40, range=(0,200000))

# %%
recent_grads["Women"].hist(bins=40, range=(0,200000))

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))
for r in range(1,8):
    ax = fig.add_subplot(8,1,r)
    ax = recent_grads[cols[r]].plot(kind='hist', rot=40)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[["Sample_size","Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b011b41d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b010f9908>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b010a0a58>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4b00dace48>]], dtype=object)

# %%
recent_grads[:5]['Women'].plot(kind='bar')

# %%
recent_grads[:5].plot(x='Major', y='Women')

# %%
recent_grads.sort_values("Median")
recent_grads[:10].plot(x="Major", y="ShareWomen", kind="bar")
recent_grads[-11:-1].plot(x="Major", y="ShareWomen",kind="bar")

# %%
recent_grads[:10].plot(x="Major", y="Unemployment_rate", kind="bar")
recent_grads[-11:-1].plot(x="Major", y="Unemployment_rate",kind="bar")

# %%
recent_grads[:10].plot.bar(y=['Men', 'Women'], x="Major" )
recent_grads[-11:].plot.bar(y=['Men', 'Women'], x="Major" )

# %%
plt.style.use('fivethirtyeight')
recent_grads.plot(x="Women",y="Median",kind="hexbin",title="Women vs Median",gridsize=25)

# %%
recent_grads.plot(x="Women",y="Median",kind="bar",title="Women vs Median",gridsize=25)
